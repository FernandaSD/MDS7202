# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2023</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Pablo Badilla, Ignacio Meza D.
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Diego Cortez

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumna 1: Catherine Benavides
# - Nombre de alumna 2: Fernanda Saavedra

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/FernandaSD/MDS7202

# %% [markdown]
# ## Reglas:
#
# - Fecha de entrega: 6 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de 2 personas**.
# - **Ausentes** deberán realizar la actividad solos.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Pueden usar cualquer material del curso que estimen conveniente.
# - Asistencia obligatoria a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2 pts)

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Qué elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Qué comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# 1. Git es un sistema de control de versiones distribuido (DVCS) que permite llevar un seguimiento de todos los cambios realizados en un archivo o conjunto de archivos a lo largo del tiempo. Además, permite colaborar en equipo, llevando un registro de quién realizó algún cambio, qué cambio realizó, cuándo y por qué. Git es un sistema distribuido ya que permite que cada persona de un equipo tenga una copia local del repositorio donde puede trabajar de forma independiente y luego actualizar el servidor central.
#
# 2. Git es un sistema de control de versiones distribuido que se utiliza por medio de líneas de comando; es únicamente un software, mientras que GitHub es un servicio de alojamiento basado en web donde se trabaja por medio de una interfaz gráfica, pero que a su vez ofrece las funcionalidades de Git. Además, Git se encarga de crear un repositorio local para hacer un seguimiento de los cambios locales realizados, mientras que GitHub permite subir una copia de estos repositorios.
#
# 3. En Git, el "hash" es un código de 40 caracteres, compuesto por letras y números, que se usa para identificar (apuntar) a un blob, commit o árbol. El hash se genera a partir del contenido del objeto y cada elemento posee un hash único, y se puede encontrar en la información de un commit junto con el nombre del autor, fecha y descripción. En Git se utiliza el hash SHA1. Por ejemplo, el hash de un commit puede ser: "4015b57a143aec5156fd1444a017a32137a3fd0f".
#
# 4. Por una parte se tienen las unidades básicas de almacenamiento de Git, que son blob, commit y árbol. Todo el contenido de un archivo es almacenado en un blob, y si este es modificado un nuevo blob se encargará de almacenar el archivo completo con todos sus cambios. Todos los archivos se almacenan en un directorio o carpeta y los árboles representan directorios para blobs y otros árboles. Por otra parte, Git está compuesta por tres elementos principales: el directorio de trabajo (working directory), el área de preparación (staging area) y el repositorio (repository). El directorio de trabajo es donde se almacenan los archivos del proyecto, mientras que el área de preparación es donde se preparan los archivos para ser enviados al repositorio. El repositorio es donde se almacenan todos los cambios y versiones del proyecto a lo largo del tiempo.
# 5. Los comandos de Git que sirven para crear un repositorio y hacer seguimientos a cambios en los archivos son:
# *   git init: Inicia un nuevo repositorio en la carpeta actual.
# *   git status: Muestra el estado actual del repositorio.
# *   git add: Añade cambios en los archivos al área de preparación.
# *   git commit: Guarda los cambios realizados en los archivos en el repositorio.
# *   git log: Muestra el historial de cambios realizados.
# *   git branch: Para ver las ramas disponibles en el repositorio o crea una nueva rama.
# *   git checkout: Cambia entre ramas o restaura archivos a versiones anteriores.
# *   git merge: Fusiona cambios entre dos ramas del repositorio.
# *   git remote: Muestra o configura conexiones con repositorios remotos.
# *   git pull: Obtener el registro de cambios de un repositorio remoto.
# *   git push: Envía los cambios realizados en el repositorio local a un repositorio remoto

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. Cada miembro del equipo trabaja en la misma copia del código fuente usando `Git`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. Falso. Cuando varias personas trabajan en las mismas líneas pueden haber colisiones entre diferentes ramas. Estas colisiones se denominan conflictos y se deben resolver manualmente antes de subir los cambios al repositorio para garantizar que el código se integre correctamente
#
# 7. Falso.  "git clone" crea una copia local de un repositorio remoto completo en una nueva carpeta y “git pull” actualiza un repositorio local existente con los cambios del repositorio remoto.
#
# 8. Falso. En Git, cada miembro del equipo tiene una copia del repositorio, con lo que pueden trabajar en el código fuente sin afectar a los demás. Los diferentes comandos de git permiten hacer cambios a nivel local o al repositorio central según necesidad, facilitando el trabajo colaborativo.
#
# 9. Verdadero. Git almacena un historial completo de todos los cambios realizados en el código, lo que permite a los usuarios deshacer cambios o volver a versiones anteriores de manera fácil y eficiente. Por ejemplo, se puede utilizar el comando git checkout.
#
# 10. Falso. El comando “git commit” se utiliza para guardar los cambios, y “git push” es el comando utilizado para enviar los cambios al repositorio remoto.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (2 pts)

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Crear y modificar un archivo `readme.md` con la información que ustedes deseen compartir.
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/pbadillatorrealba/pbadillatorrealba).
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1: https://github.com/cathylamusarana/cathylamusarana</code>
#
# <code>Link Presentacion 2: https://github.com/FernandaSD/FernandaSD</code>

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)

# %% [markdown]
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (incluya también los comandos en `Git` ocupados):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# Comando: git clone https://github.com/MDS7202/lab1.git

# %% [markdown]
# ![imagen_2023-03-29_145639536.png](data:image/png;base64,...)

# %% [markdown]
# 2. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también de cada componente que lo conforma. (0.25 pts)

# %% [markdown]
# El objetivo del proyecto consiste en emular sonidos de animales. Para ello se creó un árbol con 3 ramas. La primera es la rama principal del proyecto (main), la cual contiene 3 archivos, uno llamado animales.py que imprime el sonido de un animal. El segundo archivo se llama main.py y en este se consulta al usuario por el animalito que cuyo sonido se quiere conocer. El tercer archivo se llama readme.md y entrega información general del proyecto. La segunda rama se llama fix-ifs y en ella se busca arreglar parte del código original, y la tercera rama es una que se llama features la cual contiene una copia de los archivos de la rama main.

# %% [markdown]
# 3. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# Comando: git log --all --decorate --graph

# %% [markdown]
# Los commits entregan información sobre la fecha, hora y el nombre del usuario y correo del usuario que realizó el “commit”. Pese a eso, los comentarios adjuntos en los commits no entregan mucha información sobre los cambios realizados al repositorio.
#
# En el repositorio se pueden observar 4 commits. En el primero (el de más abajo) inicializa la rama principal, en el segundo se realizan cambios a esta rama. En el tercer commit se crea la rama new features a partir de la rama principal y en el cuarto se crea la rama fix-ifs.

# %% [markdown]
# ![imagen_2023-03-29_153337491.png](data:image/png;base64,...)

# %% [markdown]
# 4. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# El error se encuentra en el control de flujo de la función animales, al utilizarce múltiples if seguidos en vez de usar el condicional elif para condiciones excluyentes. El error lo cometió mezosky.

# %% [markdown]
# Comando:
#
#
# *   git blame main.py
# *   git blame animales.py

# %% [markdown]
# ![imagen_2023-03-29_154438829.png](data:image/png;base64,...)

# %% [markdown]
# 5. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# En el commit c8b1... se agrega una función a la rama main, en el commit 362f... se crea una nueva rama a partir de la rama main, por lo que no existen cambios entre los archivos de las ramas.
#
# En el commit 2554... se introducen cambios al archivo main.py, específicamente a la función animales. Al comparar este commit con el commit 362f... se puede ver la actualización hecha al control de flujo de la función, particularmente al cambiar las sentencias if por elif.

# %% [markdown]
# ![imagen_2023-03-29_173111913.png](data:image/png;base64,...)

# %% [markdown]
# 6. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# Al querer hacer merge entre ambas ramas se genera un conflicto con el archivo main.py, dado que este archivo fue modificado en ambas ramas. Al utilizar el comando git status se puede observar que efectivamente este archivo genera el conflicto.
#
# Por otra parte, al abrir este archivo en un editor de texto se podrán encontrar marcadores de conflicto, donde se verán los cambios de la rama principal <<<<<<< HEAD, luego aparecerá =======, que divide estos cambios de los realizados en la otra rama, para finalmente terminar con >>>>>>> origin/fix-ifs.
#
# Por lo tanto, la función animales en el archivo main.py de la rama fix-ifs es la que esta causando el conflicto ya que en main.py de la rama principal no se encuentra esta función ya que está en un archivo aparte (animales.py).

# %% [markdown]
# ![imagen_2023-03-29_172959965.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2023-03-29_212807020.png](data:image/png;base64,...)

# %% [markdown]
# 7. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.5 pts)

# %% [markdown]
# Con el comando 'git branch nueva_rama' se crea una nueva rama y con 'git checkout nueva_rama' cambiamos a ella y podemos notar que posee los tres archivos de la rama principal.
#
# Como el problema en la rama principal se da dentro de la función animales, en la nueva rama se va a realizar el cambio directamente en el archivo animales.py (y no en main.py como se hizo en la rama fix-ifs). El cambio consiste en modificar los 'if' para perro y fox por un 'elif'.
#
# Luego de realizado el cambio se hace el commit correspondiente para ahora sí poder realizar el merge entre esta nueva rama y la principal.

# %% [markdown]
# ![imagen_2023-03-29_213321772.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![imagen_2023-03-29_213934819.png](data:image/png;base64,...)

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <img src=https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif height=300>
